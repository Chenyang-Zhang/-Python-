# %%
import pandas as pd 
import matplotlib.pyplot as plt
from gen_wordcloud import *

# %%
#read data
python = pd.read_excel('../data/Github_python.xlsx')
java = pd.read_excel('../data/Github_java.xlsx')
C = pd.read_excel('../data/Github_C.xlsx')
java_s = pd.read_excel('../data/Github_javascript.xlsx')
Cpp = pd.read_excel('../data/Github_Cpp.xlsx')
C_sharp = pd.read_excel('../data/Github_C#.xlsx')

# %%
#add a language column
python['Language'] = 'Python'
java['Language'] = 'Java'
C['Language'] = 'C'
java_s['Language'] = 'JavaScript'
Cpp['Language'] = 'C++'
C_sharp['Language'] = 'C#'

# %%
#concat to one DataFrame
data = pd.concat([python, java, C, java_s, Cpp, C_sharp], axis = 0, ignore_index = True)
data.to_excel('../data/Github_all.xlsx')
data = data.drop(['Unnamed: 0'], axis = 1)
data = data.set_index('Full Name')

# %%
#select rows with stats > 10000
data = data[data['Stars'] >= 10000]
data = data.sort_values(by = 'Stars', ascending = False)

# %%
#draw pie chart
x  = data.groupby('Language').apply(len)
x.plot(kind = 'pie', subplots = True, autopct = '%.2f')
plt.title('Pie Chart')
plt.savefig('../picture/pie.png')
plt.show()

# %%
#generate wordcloud
wordcloud = gen_wordcloud(data.reset_index())
plt.imshow(wordcloud)
plt.axis('off')
plt.show()
wordcloud.to_file('../picture/wordcloud_all.jpg')

# %%
print(data)
# Out:
#                                                                            Description  \
# Full Name
# freeCodeCamp/freeCodeCamp            The https://www.freeCodeCamp.org open source c...
# vuejs/vue                            🖖 Vue.js is a progressive, incrementally-adopt...
# tensorflow/tensorflow                An Open Source Machine Learning Framework for ...
# airbnb/javascript                                               JavaScript Style Guide
# d3/d3                                Bring data to life with SVG, Canvas and HTML. ...
# ...                                                                                ...
# alibaba/Sentinel                     A lightweight powerful flow control component ...
# notepad-plus-plus/notepad-plus-plus                      Notepad++ official repository
# alibaba/vlayout                      Project vlayout is a powerfull LayoutManager e...
# google/yapf                                               A formatter for Python files
# gnab/remark                          A simple, in-browser, markdown-driven slidesho...
#
#                                       Stars  Forks Created Time    Size  \
# Full Name
# freeCodeCamp/freeCodeCamp            307326  23319   2014-12-24  121800
# vuejs/vue                            153619  22957   2013-07-29   27872
# tensorflow/tensorflow                138673  78938   2015-11-07  455476
# airbnb/javascript                     91024  17661   2012-11-01    3044
# d3/d3                                 88968  21621   2010-09-27   41490
# ...                                     ...    ...          ...     ...
# alibaba/Sentinel                      10062   3029   2018-04-04    4354
# notepad-plus-plus/notepad-plus-plus   10043   2550   2015-03-28  181704
# alibaba/vlayout                       10026   1725   2017-02-27    1600
# google/yapf                           10016    687   2015-03-18    2360
# gnab/remark                           10005    781   2011-10-11    6314
#
#                                        Owner Type  \
# Full Name
# freeCodeCamp/freeCodeCamp            Organization
# vuejs/vue                            Organization
# tensorflow/tensorflow                Organization
# airbnb/javascript                    Organization
# d3/d3                                Organization
# ...                                           ...
# alibaba/Sentinel                     Organization
# notepad-plus-plus/notepad-plus-plus  Organization
# alibaba/vlayout                      Organization
# google/yapf                          Organization
# gnab/remark                                  User
#
#                                                                         Owner Location  \
# Full Name
# freeCodeCamp/freeCodeCamp                                                   Flavortown
# vuejs/vue                                                                   Flavortown
# tensorflow/tensorflow                                                              NaN
# airbnb/javascript                                                           Flavortown
# d3/d3                                                                       Flavortown
# ...                                                                                ...
# alibaba/Sentinel                                                       Hangzhou, China
# notepad-plus-plus/notepad-plus-plus                                                NaN
# alibaba/vlayout                                                        Hangzhou, China
# google/yapf                          2788 San Tomas Expressway, Santa Clara, CA, 95051
# gnab/remark                                                           Guangzhou, China
#
#                                      Owner Followers  Repo_num  \
# Full Name
# freeCodeCamp/freeCodeCamp                          0        55
# vuejs/vue                                          0        55
# tensorflow/tensorflow                              0        13
# airbnb/javascript                                  0        55
# d3/d3                                              0        55
# ...                                              ...       ...
# alibaba/Sentinel                                   0       287
# notepad-plus-plus/notepad-plus-plus                0        53
# alibaba/vlayout                                    0       287
# google/yapf                                        0       169
# gnab/remark                                     2086        82
#
#                                                            Company    Language
# Full Name
# freeCodeCamp/freeCodeCamp                                      NaN  JavaScript
# vuejs/vue                                                      NaN  JavaScript
# tensorflow/tensorflow                                          NaN         C++
# airbnb/javascript                                              NaN  JavaScript
# d3/d3                                                          NaN  JavaScript
# ...                                                            ...         ...
# alibaba/Sentinel                                               NaN        Java
# notepad-plus-plus/notepad-plus-plus                            NaN         C++
# alibaba/vlayout                                                NaN        Java
# google/yapf                                                    NaN      Python
# gnab/remark                          Scutech Corporation @scutech   JavaScript
#
# [620 rows x 11 columns]

# %%
data_loc = data[data['Owner Location'] != 'NaN']
data.to_excel('../data/Github_loc.xlsx')

# %%
data_loc.groupby('Owner Location').apply(len)
# Out:
# Owner Location
# #mpv @ freenode                                                                       30
# 2788 San Tomas Expressway, Santa Clara, CA, 95051                                     29
# Beijing, China                                                                        34
# Canada, Colombia, Italy, Japan, Perú, Spain, Russia, Thailand, UK, Ukranie and USA    30
# Chengdu                                                                               30
# Colorado                                                                              30
# Flavortown                                                                            30
# Guangzhou, China                                                                      22
# Hangzhou, China                                                                       76
# Netherlands                                                                           30
# Palo Alto, California                                                                 30
# San Francisco, CA                                                                     30
# Seagrove Beach, FL                                                                    30
# Universe                                                                              30
# Worldwide                                                                             30
# dtype: int64
